# %%
import pandas as pd

# %%
# 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
레모네이드 = pd.read_csv(파일경로)
레모네이드.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 데이터 모양으로 확인
print(레모네이드.shape)
# Out:
# (6, 2)

# %% [markdown]
# (6,2) 형태로 데이터가 구성되어 있다.

# %%
# 칼럼이름 출력
print(레모네이드.columns)
# Out:
# Index(['온도', '판매량'], dtype='object')

# %%
# 종속변수, 독립변수
독립 = 레모네이드[['온도']]
종속 = 레모네이드[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)
