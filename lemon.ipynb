# %% [markdown]
# # 머신러닝 야학 레모네이드 판매 예측 실습

# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %% [markdown]
# 실습에 필요한 라이브러리입니다.

# %%
# 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
레모네이드 = pd.read_csv(파일경로)
레모네이드.head()
# 종속변수, 독립변수
독립 = 레모네이드[['온도']]
종속 = 레모네이드[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %% [markdown]
# 데이터를 준비하고 종속변수와 독립변수로 분리하는 작업입니다.

# %%
# 모델을 만듭니다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %% [markdown]
# 모델 구조를 만드는 작업입니다.

# %%
# 모델을 학습시킵니다. 
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 466ms/step - loss: 3682.0940
# Epoch 2/10
# 1/1 [==============================] - 0s 6ms/step - loss: 3673.0569
# Epoch 3/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3666.5117
# Epoch 4/10
# 1/1 [==============================] - 0s 7ms/step - loss: 3661.0378
# Epoch 5/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3656.1829
# Epoch 6/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3651.7375
# Epoch 7/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3647.5852
# Epoch 8/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3643.6531
# Epoch 9/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3639.8923
# Epoch 10/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3636.2676

# %%
# 모델을 학습시킵니다. 
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0304
# Epoch 2/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0304
# Epoch 3/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0303
# Epoch 4/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0303
# Epoch 5/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0303
# Epoch 6/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0303
# Epoch 7/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0303
# Epoch 8/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0302
# Epoch 9/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0302
# Epoch 10/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0302

# %% [markdown]
# Loss가 많이 줄어드는 것을 확인하였습니다.

# %%
# 모델을 이용합니다. 
print(model.predict(독립))
# Out:
# [[40.255527]
#  [42.153786]
#  [44.05204 ]
#  [45.9503  ]
#  [47.848557]
#  [49.746815]]

# %%
종속
# Out:
#    판매량
# 0   40
# 1   42
# 2   44
# 3   46
# 4   48
# 5   50

# %%
print(model.predict([[15]]))
# Out:
# [[30.76424]]

# %% [markdown]
# 다음은 모델의 15를 넣었을때 예측하는 값입니다.
